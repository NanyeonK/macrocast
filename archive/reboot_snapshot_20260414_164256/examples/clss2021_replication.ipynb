# %% [markdown]
# # CLSS 2021 Recipe-Native Example
#
# This notebook is the canonical recipe-native demonstration path for CLSS 2021 under the tree-path package migration.
#
# Primary architectural artifact:
# - `recipes/papers/clss2021.yaml`

# %%
from macrocast.specs.compiler import compile_experiment_spec_from_recipe
compiled = compile_experiment_spec_from_recipe('papers/clss2021.yaml', preset_id='researcher_explicit')
compiled.to_contract_dict()

# %% [markdown]
# ## Runtime note
#
# Long-run target state is recipe/path-native execution.
# This notebook intentionally does not rely on CLSS-specific helper modules.
